# %% [markdown]
# ## Student: Banuka Vidusanka Paniyan Duwage
# ## CA3 – Assignment OPT-2
# ## Roll No: RDE848 A032
# ## Student id: 11917550

# %%
print ('''Q1. Write a Python program to take input of 10 numbers, find 
the square of all 10 numbers and check whether the square of every number 
is palindrome or not. Numbers where square is palindrome, save in file 
with original numbers and their squares. Numbers where square is 
not palindrome, must be saved in separate file.\n''')

import datetime  #datetime module used to get current system time.
import os  #os module used to check for file exisitence.

TEN = 10  #Control number of inputs accepted in program
FILE1 = "11917550_only_palindromes.txt" #preset file names
FILE2 = "11917550_not_palindromes.txt" #so it can be modified from one place

# isPalindrome() - CHECKS FOR PALINDROME
# (using python-ternary-op, int-string convertion & str-reverese)
def isPalindrome(numb):
    return True if (numb == int( str(numb)[::-1] )) else False

#getSqure() - Return squre of a number
def getSqure(numb):
    return numb**2

#lambda / annonymous function. (can place this instead of getSqure f-call)
#getSqure2 = lambda numb: numb**2  

# #uncomment for Testing purpose only
# input_list = [7,9,11,5,2,-5,-10,100,4,-111]

input_list = []  #this list will hold the input from user
while (len(input_list)<TEN):
    temp_msg = 'Enter Number ' + str(len(input_list) +1) + ' : '
    try:
        temp_int = int(input(temp_msg))
        input_list.append(temp_int)
    except Exception as e:
        print("***Error found: ",e)
        print("**Expecting Integer value. Please try again.")

#calculate square of each number form input_list[] and map to a new square_list[]
squre_list = list( map(getSqure, input_list) )
        
print("List of Inputs: ", input_list)
print("List of square: ", squre_list)

fh1 = open(FILE1, "w")  #open file in 'w' mode where any old content is cleared from file
fh2 = open(FILE2, "w")
#write a starting line in the files.
fh1.write(FILE1 + ": created at: " + str(datetime.datetime.now()) + "\n___Numbers for which Square is Palindrome.\n")
fh2.write(FILE2 + ": created at: " + str(datetime.datetime.now()) + "\n___Numbers for which Square is not Palindrome.\n")

#traverese list by index and write to file based on isPalindrome() function result
for xx in range(len(input_list)):
    temp_str = "{} squared is: {}\n".format(input_list[xx], squre_list[xx])
    if isPalindrome(squre_list[xx]):
        fh1.write(temp_str)
    else:
        fh2.write(temp_str)

fh1.close()  #close filehead that used to write to file
fh2.close()

print("\nDisplay Two text File contents: \n")
for fname in [FILE1,FILE2]:
    if os.path.exists(fname):
        f = open(fname, "r")
        print(f.read())
        f.close()
    
print("Finished execution at: ",datetime.datetime.now())
# Out:
# Q1. Write a Python program to take input of 10 numbers, find
# the square of all 10 numbers and check whether the square of every number
# is palindrome or not. Numbers where square is palindrome, save in file
# with original numbers and their squares. Numbers where square is
# not palindrome, must be saved in separate file.
#
# Enter Number 1 : 55
# Enter Number 2 : -121
# Enter Number 3 : 0
# Enter Number 4 : 1
# Enter Number 5 : 77
# Enter Number 6 : -9
# Enter Number 7 : 111
# Enter Number 8 : 1000
# Enter Number 9 : 1010
# Enter Number 10 : -2
# List of Inputs:  [55, -121, 0, 1, 77, -9, 111, 1000, 1010, -2]
# List of square:  [3025, 14641, 0, 1, 5929, 81, 12321, 1000000, 1020100, 4]
#
# Display Two text File contents:
#
# 11917550_only_palindromes.txt: created at: 2020-11-04 20:31:12.600574
# ___Numbers for which Square is Palindrome.
# -121 squared is: 14641
# 0 squared is: 0
# 1 squared is: 1
# 111 squared is: 12321
# -2 squared is: 4
#
# ...

# %%
print ('''Q2. Write a Python program to calculate % of death rate, 
happened due to Covid-19 in all over INDIA with the help of function. 
% of death rate must be returned by the function. All required values 
must be entered on run time like total cases, no. of deaths etc.\n''')

import datetime  #datetime module used to get current system time.

## getDeathRate() - returns "Infection Fatality Rate (IFR)" = Deaths / Cases 
def getDeathRate(totD,totC):
    try:
        #expect ZeroDivisionError incase total-Cases or population is set to 0 by user
        return (totD/totC)*100
    except:
        return 0

## getInfectedPr() - returns "Presentage of population infected with covid-19"
def getInfectedPr(totC,pop):
    try:
        return (totC/pop)*100
    except:
        return 0

## getRecoveryRate() - returns "Recovery rate of patient once infected"
def getRecoveryRate(totR,totC):
    try:
        return (totR/totC)*100
    except:
        return 0

country = 'India'
resource = "https://www.worldometers.info/coronavirus/"
dataRetrievedOn = datetime.datetime.now()
##default static data - will be used if user input has any error.
population = 1384678624
totalCases = 8364086
totalDeaths = 124354
totalRecovered = 7711809
resetData = False

print("Please enter integer values as input. \nIf user input is Erroneous, program will use default static data for calclulations.\n")
try:
    ##try to get dynamic data input from user
    country = input("Enter Country: ")
    population = int(input("Enter Population of the Country: "))
    totalCases = int(input("Enter Total covid-19 positive cases recorded sofar: "))
    totalDeaths = int(input("Enter Total covid-19 deaths recorded in india: "))
    totalRecovered = int(input("Enter Total covid-19 recovered patients: "))
except Exception as e:
    print("***Error found: ",e)
    print("\nProgram will use default data stored to calculate results.")
    resetData = True
finally:
    ##cleanup code makes sure user input is acceptable, if not reset data.
    if(population<0 or totalCases<0 or totalRecovered<0):
        print("Expecting positive integer values for input.")
        resetData = True
    elif(population<totalCases):
        print("Total covid cases recorded must be less than actual population!")
        resetData = True
    elif( totalCases<(totalDeaths+totalRecovered) ):
        print("Sum of total deaths and recovered cannot be larger than Total covid confirmed cases!")
        resetData = True
        
    if(resetData):
        print("\nUser has entered bad data. Program will use default data stored to calculate results.")
        country = 'India'
        population = 1380004385
        totalCases = 8335273
        totalDeaths = 123783
        totalRecovered = 7675269
    
##call user defined functions to calculate deathRate and other values.
deathRate = getDeathRate(totalDeaths, totalCases)
infectedPresentage = getInfectedPr(totalCases, population)
recoveryRate = getRecoveryRate(totalRecovered, totalCases)
activeCasesRate = 100-deathRate-recoveryRate

print("\nAccording to Data retrieved from: {} \nOn the date: {}".format(resource,dataRetrievedOn) )
print("{}, a country of {:,} population had total of {:,} confirmed Covid-19 cases.".format(country,population,totalCases) )
print("There has been {:,} covid related deaths, and {:,} patients recovered.".format(totalDeaths,totalRecovered) )

print("\nIn {}, Covid-19 Death Rate (Infection Fatality Rate) is recorded as: {:.4f}%".format(country, deathRate))
print("\n{:.4f}% of {}'s population has contracted the virus with a recovery rate of {:.4f}%".format(infectedPresentage,country,recoveryRate))


print('\n***Attempt to create pie chart to better display data.***')
import matplotlib.pyplot as plotter # import the pyplot library

print("Result of Covid cases recoreded in:", country)
pieLabels= 'Covid Infection Fatality Rate%', 'Covid Recovery Rate%', 'Active Cases Rate%'
dataforpie = [deathRate, recoveryRate, activeCasesRate ]
figureObject, axesObject = plotter.subplots()
# Draw the pie chart
axesObject.pie(dataforpie, labels=pieLabels, autopct='%1.2f', startangle=90)

axesObject.axis('equal') # Aspect ratio - equal means pie is a circle
plotter.show()
# Out:
# Q2. Write a Python program to calculate % of death rate,
# happened due to Covid-19 in all over INDIA with the help of function.
# % of death rate must be returned by the function. All required values
# must be entered on run time like total cases, no. of deaths etc.
#
# Please enter integer values as input.
# If user input is Erroneous, program will use default static data for calclulations.
#
# Enter Country: India
# Enter Population of the Country: 1380004385
# Enter Total covid-19 positive cases recorded sofar: 8335273
# Enter Total covid-19 deaths recorded in india: 123783
# Enter Total covid-19 recovered patients: 7675269
#
# According to Data retrieved from: https://www.worldometers.info/coronavirus/
# On the date: 2020-11-05 11:59:17.175325
# India, a country of 1,380,004,385 population had total of 8,335,273 confirmed Covid-19 cases.
# There has been 123,783 covid related deaths, and 7,675,269 patients recovered.
#
# ...

# %%
print ('''Q3. Write a Python program to demonstrate the advantages of 
exception handling with any three exceptions and with the help of any 
one of the concepts (Dictionaries, Flow Controls, and Data Types).\n''')

marksDict = {"PHP":59, "Python":89, "Java":'79', "C#":'FIFTY'}

print("\nDemonstrate use of Exception handling: with Dictionary")
print(marksDict)

print("\nAttempt to access a non-exisiting variable.")
try:
    print(marksDictNOT)
except NameError as ne:
    print("**NameError Occored:", ne)
except Exception as ex:
    print("***Some Error Occored:", ex)
finally:
    print("Having used try-except, NameError is recognized and dealt with.")



print("\nAttempt to access a non-exisiting key of dictionary.")
try:
    print(marksDict["HTML"])
except KeyError as ke:
    print("**KeyError Occored:", ke)
except Exception as ex:
    print("***Some Error Occored:", ex)
finally:
    print("Having used try-except, KeyError is recognized and dealt with.")

    
print("\nAttempt to add int to string using + sign.")
try:
    totalMarks = marksDict["PHP"] + marksDict["Python"] + marksDict["Java"]
except TypeError as te:
    print("**TypeError Occored:", te)
except Exception as ex:
    print("***Some Error Occored:",type(ex), ex)
finally:
    print("Having used try-except, TypeError is recognized and dealt with.")
    
    
print("\nAttempt to convert string to int.")
try:
    print("Java marks value type before:", type(marksDict["Java"]) )
    marksDict["Java"] = int(marksDict["Java"])
    print("Java marks value type after:", type(marksDict["Java"]) )
except Exception as ex:
    print("***Some Error Occored:",type(ex), ex)
    print("Converting string to int failed in Java marks!")
else:
    print("Code ran succesfully. String converted to int value and assigned to Java in marksDict")
    
       
print("\nAttempt to convert string to int AGAIN!.")
try:
    print("C# marks value type before:", type(marksDict["C#"]) )
    marksDict["C#"] = int(marksDict["C#"])
    print("C# marks value type after:", type(marksDict["C#"]) )
except ValueError as ve:
    print("**ValueError Occored:", ve)
    print("Converting string to int failed in C# marks!")
except Exception as ex:
    print("***Some Error Occored:",type(ex), ex)
    print("Converting string to int failed in C# marks!")
else:
    print("Code ran succesfully. String converted to int value and assigned to C# in marksDict")
    
    
marksList = list(marksDict.values())
print("\nGet values of dictionary as a list", marksList)
print("Attempt to access list item by index.")
try:
    print("Index 5 has value", marksList[5])
except IndexError as ie:
    print("**IndexError Occored:", ie)
    print("Accessing array by index failed!")
except Exception as ex:
    print("***Some Error Occored:",type(ex), ex)
    
print("\n====================*******======================\n")
print("Practicle program that makes use of Exception handling.")
print("Program to calculate and store Student marks in to file.")

dict1 = {} #cictionary to store exam marks
flag4Loop = True #boolean value used to control while-loop
while flag4Loop:
    try:
        print("\nEnter marks section. Input other than integer would result in exception")
        dict1["Maths"] = int(input("Enter marks for Maths: ")) #save as integer value
        dict1["English"] = str(int(input("Enter marks for English: "))) #save as string value
        flag4Loop = False
    except ValueError as ve:
        print("**ValueError Occored:", ve)
        print("Please try again.")
    except Exception as ex:
        print("***Some Error Occored:",type(ex), ex)

print("\nCalculate total makrs section:")    
totalMarks = 0
try:
    totalMarks = dict1["Maths"] + dict1["English"] #attempt to add (str + int)
except TypeError as te:
    print("**TypeError Occored:", te)
    print("Addition failed")
except Exception as ex:
    print("***Some Error Occored:",type(ex), ex)
    
print("Convert data type of both marks to int")
try:
    dict1["Maths"] = int(dict1["Maths"])
    dict1["English"] = int(dict1["English"])
except Exception as ex:
    print("***Some Error Occored:",type(ex), ex)
else:
    print("Both Values in dictionary are now integer. try to get Total again!")
    
    
try:
    totalMarks = dict1["Maths"] + dict1["English"]
except TypeError as te:
    print("**TypeError Occored:", te)
    print("Addition failed")
except Exception as ex:
    print("***Some Error Occored:",type(ex), ex)
else:
    print("Code run successfully. TotalMarks:", totalMarks)
    
print("\nRetrieve marks section. (Try Providing subject not avilable in dictionary.)")
subject = input("Enter name of subject to retrieve marks: ")
try:
    print("Marks for:",subject, " is", dict1[subject])
except KeyError as ke:
    print("**KeyError Occored:", ke)
    print("Entered subject does not exisit in Dictionary.")
    try:
        newMarks = int(input("Enter new marks for subject to add to dictionary: "))
        dict1[subject] = newMarks
        print("Newly added Marks for:",subject, "is:", dict1[subject])
    except Exception as ex:
        print("***Some Error Occored:",type(ex), ex)
   
print("\nSection to raise exception if subject-marks are not in range 0-100.")    
class Error(Exception):
    pass 

class MyEx_Over100(Error):
    pass

class MyEx_Under0(Error):
    pass

try:
    if dict1["Maths"] > 100 or dict1["English"] > 100:
        raise MyEx_Over100
    elif dict1["Maths"] < 0 or dict1["English"] < 0:
        raise MyEx_Under0
except MyEx_Over100:
    print("***Exam Marks cannot be larger than 100.")
except MyEx_Under0:
    print("***Exam Marks cannot be less than 0.")    
except Exception as ex:
    print("***Some Error Occored:",type(ex), ex)
else:
    print("Marks were in acceptable range of: 0-100.")
# Out:
# Q3. Write a Python program to demonstrate the advantages of
# exception handling with any three exceptions and with the help of any
# one of the concepts (Dictionaries, Flow Controls, and Data Types).
#
#
# Demonstrate use of Exception handling: with Dictionary
# {'PHP': 59, 'Python': 89, 'Java': '79', 'C#': 'FIFTY'}
#
# Attempt to access a non-exisiting variable.
# **NameError Occored: name 'marksDictNOT' is not defined
# Having used try-except, NameError is recognized and dealt with.
#
# Attempt to access a non-exisiting key of dictionary.
# **KeyError Occored: 'HTML'
# Having used try-except, KeyError is recognized and dealt with.
#
# Attempt to add int to string using + sign.
# **TypeError Occored: unsupported operand type(s) for +: 'int' and 'str'
# Having used try-except, TypeError is recognized and dealt with.
#
# Attempt to convert string to int.
# Java marks value type before: <class 'str'>
# Java marks value type after: <class 'int'>
# ...
